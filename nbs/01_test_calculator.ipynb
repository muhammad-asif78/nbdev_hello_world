# %%
#| hide
from nbdev_hello_world.calculator import calculator_logic
calculator_logic(5, 3, '+')
# Out:
# Enter first number:  78
# Enter second number:  844
# Enter operation (+, -, *, /):  -
# Result: -766.0

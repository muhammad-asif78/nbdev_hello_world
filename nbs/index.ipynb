# %%
#| hide
from nbdev_hello_world.core import *

# %% [markdown]
# # nbdev_hello_world
#
# > hello this is my first repo

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbdev_hello_world in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev_hello_world package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev_hello_world
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/muhammad-asif78/nbdev_hello_world.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c muhammad-asif78 nbdev_hello_world
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev_hello_world
# ```
#
#
# [repo]: https://github.com/muhammad-asif78/nbdev_hello_world
# [docs]: https://muhammad-asif78.github.io/nbdev_hello_world/
# [pypi]: https://pypi.org/project/nbdev_hello_world/
# [conda]: https://anaconda.org/muhammad-asif78/nbdev_hello_world

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/muhammad-asif78/nbdev_hello_world
# [docs]: https://muhammad-asif78.github.io/nbdev_hello_world/
# [pypi]: https://pypi.org/project/nbdev_hello_world/
# [conda]: https://anaconda.org/muhammad-asif78/nbdev_hello_world

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2

# %%
# hello my name is asif

# %%
#| export
def say_hello(to):
    "Say hello to somebody"
    return f'Hello {to}!'

# %%
say_hello("Isaac")
